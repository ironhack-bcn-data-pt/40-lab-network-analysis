# %% [markdown]
# # Network Analysis Lab
#
# Complete the following exercises to help solidify your understanding of network analysis.

# %%
import networkx as nx
import community
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import igviz as ig
import community as louvain

# %% [markdown]
# ## U.S. Mens Basketball Data Set
#
# In the `us_mens_basketball.csv` data set, each row represents an single basketball player's participation in a single event at a single Olympics.

# %%
basketball = pd.read_csv('../data/us_mens_basketball.csv')

# %%
basketball.head()
# Out:
#      ID                                  Name Sex   Age  Height  Weight  \
# 0   351            Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0
# 1  2636           Stephen Todd "Steve" Alford   M  19.0   185.0    74.0
# 2  2863                      Walter Ray Allen   M  25.0   192.0    93.0
# 3  3874  William Lloyd "Willie" Anderson, Jr.   M  21.0   200.0    86.0
# 4  4505                  Carmelo Kyan Anthony   M  20.0   203.0   109.0
#
#             Team  NOC        Games  Year  Season         City       Sport  \
# 0  United States  USA  2000 Summer  2000  Summer       Sydney  Basketball
# 1  United States  USA  1984 Summer  1984  Summer  Los Angeles  Basketball
# 2  United States  USA  2000 Summer  2000  Summer       Sydney  Basketball
# 3  United States  USA  1988 Summer  1988  Summer        Seoul  Basketball
# 4  United States  USA  2004 Summer  2004  Summer       Athina  Basketball
#
#                          Event   Medal
# 0  Basketball Men's Basketball    Gold
# 1  Basketball Men's Basketball    Gold
# 2  Basketball Men's Basketball    Gold
# 3  Basketball Men's Basketball  Bronze
# 4  Basketball Men's Basketball  Bronze

# %% [markdown]
# ## 1. Transform this data set into one that can be turned into a graph where the entities are represented by the Name field and the relationships are represented by whether the players played in the same Olympics together (Games field).
#
# Sort descending by the number of pairwise interactions. Which pair of players have competed in the most Olympics together?

# %%
basketball.isnull().sum()
# Out:
# ID        0
# Name      0
# Sex       0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
'''First, we need to create a new dataset where the index is the name of the player and groupby Games, then
we will turn that groupby into a pivot table where the names, games and whether they played together or not are colums
'''

#we make a copy of the dataset to merge them on games. 
df = basketball.copy()

#we create a dataframe with the data we are interested in:
network = df.groupby(['Games','Name']).count().reset_index().drop(['ID','Sex','Age','Height','Weight','Team','NOC','Year','Season','City','Sport','Event','Medal'], axis =1)

# %%
#creating a list with all the players per game
player_game = [network.loc[network['Games'] == game]['Name'].to_list() for game in network.Games.unique()]

# %%
#looking for players that have played together. 
connections = [list(itertools.combinations(players, 2)) for players in player_game]

#now for every time a combination is repeated, we can say thos players have played together n times.
#to count how many times they have played together we make a pandas dataframe again and count groupby.

# %%
count_games = pd.concat([pd.DataFrame(game, columns =['Name_x', 'Name_y']) for game in connections], axis=0)
edges = count_games.groupby(['Name_x','Name_y']).size().reset_index().rename(columns={0:'count'}).sort_values(by='count', 
                                                                                                      ascending=False)

# %% [markdown]
# ## 2. Use the `from_pandas_edgelist` method to turn the data frame into a graph.

# %%
G = nx.from_pandas_edgelist(edges, source='Name_x', target='Name_y')
nx.draw(G)
# Out:
# /usr/local/Cellar/jupyterlab/2.1.2/libexec/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# ## 3. Compute and print the following graph statistics for the graph:
#
# - Number of nodes
# - Number of edges
# - Average degree
# - Density

# %%
print("Number of nodes: ", G.size())
# Out:
# Number of nodes:  1232

# %%
print("Number of edges: ", G.order())
# Out:
# Number of edges:  196

# %%
print("Average degree: ", G.size()/G.order())
# Out:
# Average degree:  6.285714285714286

# %%
print("Density of graph: ", nx.density(G))
# Out:
# Density of graph:  0.06446886446886448

# %% [markdown]
# ## 4. Compute betweenness centrality for the graph and print the top 5 nodes with the highest centrality.

# %%
b_centrality = nx.betweenness_centrality(G)

# %%
high_b_centrality = sorted(b_centrality.items(), key=lambda x: x[1], reverse=True)[:5]

high_b_centrality
# Out:
# [('Gary Dwayne Payton', 0.09193761564895586),
#  ('Jason Frederick Kidd', 0.09135606661379858),
#  ('Carmelo Kyan Anthony', 0.04742268041237116),
#  ('David Maurice Robinson', 0.03266190853819725),
#  ('William Marion "Bill" Hougland', 0.030240549828178694)]

# %% [markdown]
# ## 5. Compute Eigenvector centrality for the graph and print the top 5 nodes with the highest centrality.

# %%
e_c = nx.eigenvector_centrality_numpy(G)

e_c
# Out:
# {'Carmelo Kyan Anthony': 0.3418500566719078,
#  'LeBron Raymone James': 0.2884535214315893,
#  'David Maurice Robinson': 0.041757387926110674,
#  'John Houston Stockton': 0.0345602759198285,
#  'Scottie Maurice Pippen': 0.03456027591982852,
#  'Christopher Emmanuel "Chris" Paul': 0.22431681558531288,
#  'Deron Michael Williams': 0.2243168155853129,
#  'Kobe Bean Bryant': 0.2243168155853129,
#  'Christopher Paul "Chris" Mullin': 0.027955776108380667,
#  'Michael Jeffrey Jordan': 0.02795577610838065,
#  'Dwyane Tyrone Wade, Jr.': 0.2219569476356045,
#  'Patrick Aloysius Ewing': 0.02795577610838066,
#  'Carlos Austin Boozer, Jr.': 0.22195694763560453,
#  'Karl Malone': 0.034560275919828486,
#  'Kevin Wayne Durant': 0.20010776925533366,
#  'Charles Wade Barkley': 0.03456027591982849,
#  'Mitchell James "Mitch" Richmond, III': 0.03129100666212815,
#  'Jerry Ray Lucas': -2.4934237772854936e-17,
#  'Lester Everett "Les" Lane': -2.6004742137894374e-17,
#  'Robert Lewis "Bob" Boozer': -3.5692360427102816e-17,
#  'Oscar Palmer Robertson': -2.729551138929243e-17,
#  'Jeffrey Stephen "Jeff" Turner': 0.011572567846821983,
#  'Jon Francis Koncak': 0.01157256784682199,
#  'Jerry Franklin Shipp': -3.9431725163879986e-18,
#  'William Warren "Bill" Bradley': -1.2686961841889147e-17,
#  'Jay Joseph Hoyland Arnette': -2.169704128877525e-17,
#  'Terence Gilbert "Terry" Dischinger': -2.600902270272127e-17,
#  'Walter Raphael "Walt" Hazzard': -1.7115112566628083e-17,
#  'Velvet James "Jim" Barnes': -2.5610070733293333e-18,
#  'Richard Allen "Dick" Davies': 4.439716294200933e-18,
#  'Walter Jones "Walt" Bellamy, Jr.': -4.8174933201742954e-17,
#  'Lucious Brown "Luke" Jackson, Jr.': 1.0184034292329604e-17,
#  'Jesse Banard Renick': -4.2039730873630383e-16,
#  'Kenneth Herman "Kenny" Rollins': -4.238530578808114e-16,
#  'Lewis William "Lew" Beck, Jr.': -4.53117343149557e-16,
#  'Ralph Milton Beard, Jr.': -4.324650351271881e-16,
#  'Raymond George "Ray" Lumpp': -4.1008485253256547e-16,
#  'Robert Albert "Bob" Kurland': -8.824136966346834e-16,
#  'Robert C. "R. C." Pitts': -4.3245133731974204e-16,
#  'Robert Lloyd Jackson "Jack" Robinson': -4.255740835493421e-16,
#  'Vincent Joseph "Vince" Boryla': -4.272814114104268e-16,
#  'Wallace Clayton "Wally" Jones': -4.204110065437499e-16,
#  'Jimmy Butler III': 0.08675377951546032,
#  'Melvin Grant "Mel" Counts': -1.6279162258999554e-17,
#  'Joseph Louis "Joe" Caldwell': -5.4474672221165996e-18,
#  'Lawrence Harvey "Larry" Brown': -1.2892273628304019e-17,
#  'Joseph William "Joe" Kleine': 0.011572567846821992,
#  'Osie Leon Wood, III': 0.011572567846821992,
#  'Samuel Bruce "Sam" Perkins': 0.011572567846821999,
#  'Stephen Todd "Steve" Alford': 0.011572567846822,
#  'Jeffrey "Jeff" Grayer': 0.011693205660835225,
#  'William Lloyd "Willie" Anderson, Jr.': 0.011693205660835251,
#  'Vernon "Vern" Fleming': 0.011572567846821988,
#  'Wayman Lawrence Tisdale': 0.011572567846822004,
#  'Jeffrey Vincent "Jeff" Mullins': 5.982515226296838e-18,
#  'John Paul "Pete" McCaffrey': -2.1752881124136088e-17,
#  'Vernell Eufaye "Bimbo" Coles': 0.011693205660835244,
#  'Stacey Orlando Augmon': 0.011693205660835248,
#  'Jerome Alan "Jerry" West': -3.935210831162678e-17,
#  'Klay Alexander Thompson': 0.08675377951546029,
#  'John Frederick Keller': -5.412008417797729e-16,
#  'Ronald Yngve "Ron" Bontemps': -5.222764083296579e-16,
#  'Kyle Lowry': 0.0867537795154603,
#  'Kyrie Andrew Irving': 0.08675377951546032,
#  'Joseph Cephis "Joe" Fortenberry': -3.717483928677104e-18,
#  'William John "Bill" Wheatley': 1.1667179379195207e-17,
#  'Willard Theodore Schmidt': -1.7716227518866187e-17,
#  'Samuel J. "Sam" Balter, Jr.': 1.6424106813623118e-19,
#  'Ralph English Bishop': -1.9743679353904237e-17,
#  'John Richard Clawson': -9.858587416382591e-19,
#  'Wilmer Frederick "Bill" Hosket': -1.9608431778393947e-17,
#  'Spencer Haywood': -9.552530881385806e-18,
#  'Michael Thomas "Mike" Barrett': 7.966659532005455e-18,
#  'Joseph Henry "Jo-Jo" White': 7.81963094346315e-18,
#  'Michael Barnwell "Mike" Silliman': -1.382369879701826e-17,
#  'William Barner "Bill" Lienhard': -5.360446136779037e-16,
#  'John Haskell "Tex" Gibbons': 3.7252037297954e-19,
#  'William Marion "Bill" Hougland': -6.43776611978223e-16,
#  'Victor Wayne Glasgow': -5.222832572333809e-16,
#  'Jason Frederick Kidd': 0.18566925214703778,
#  'Walter Ray Allen': 0.039276863784598215,
#  'Robert Earl "Bob" Kenney': -5.06752932794266e-16,
#  'Melvin Dean Kelley': -5.27425787527804e-16,
#  'Marcus Ross "Marc" Freiberger': -5.170996335166196e-16,
#  'Paul George': 0.0867537795154603,
#  'Larry Joe Bird': 0.021545202099102902,
#  'John Kenneth "Ken" Spain': 9.628376236649155e-18,
#  "Shaquille Rashuan O'Neal": 0.02409389465584596,
#  'Reginald Wayne "Reggie" Miller': 0.02409389465584598,
#  'Adrian Delano Dantley': 7.077243712919609e-17,
#  'Ernest "Ernie" Grunfeld': 8.351726810207462e-17,
#  'Vincent Lamont "Vin" Baker': 0.039276863784598215,
#  'Gordon C. Carpenter': -4.20424704351196e-16,
#  'Grant Henry Hill': 0.024093894655845962,
#  'Glynn Saulters': 8.069673224551921e-18,
#  'Hakeem Abdul Olajuwon': 0.02409389465584596,
#  'Vincent Lamar "Vince" Carter': 0.039276863784598194,
#  'Harrison Bryce Jordan Barnes': 0.08675377951546029,
#  'Hyland DeAndre Jordan, Jr.': 0.08675377951546027,
#  'James H. "Jim" King': -1.483671042851621e-17,
#  'Gilbert "Gib" Ford': -1.7974090189908575e-16,
#  'Gary Dwayne Payton': 0.05969646937922542,
#  'Kevin Maurice Garnett': 0.03927686378459821,
#  'Timothy Duane "Tim" Hardaway': 0.03927686378459822,
#  'Steven Delano "Steve" Smith': 0.03927686378459821,
#  'William Fenton "Bill" Russell': -1.8059970250742034e-16,
#  'Julius Shareef Abdur-Rahim': 0.03927686378459821,
#  'Frank Reilly McCabe': -5.102292286499427e-16,
#  'George "Jiff" Wilson': 5.051237523907117e-18,
#  'William Best "Billy" Evans': -1.9566210155892584e-16,
#  'Ronald Paul "Ron" Tomsic': -1.8058600469997428e-16,
#  'Robert Eugene "Bob" Jeangerard': -1.9135611293573748e-16,
#  'Richard James "Dick" Boushka': -2.0297303619831997e-16,
#  'K. C. Jones': -1.7972891631757043e-16,
#  'James Patrick "Jim" Walsh': -1.7714737781477432e-16,
#  'Herman "J. R." Reid, Jr.': 0.011693205660835253,
#  'Hersey R. Hawkins, Jr.': 0.01169320566083524,
#  'James Ricardo "Jim" Forbes': 2.2175438685237627e-18,
#  'Thomas Edward "Tom" Henderson': 1.9468179169329427e-17,
#  'Robert Clyde "Bobby" Jones': 7.109912898076868e-18,
#  'Paul Douglas "Doug" Collins': 9.57474478467179e-18,
#  'Michael Allen "Mike" Bantom': 1.2981079086097414e-17,
#  'Kevin Francis Joyce': 1.404187365325964e-17,
#  'Kenneth Bryan "Kenny" Davis': 1.3884628650658212e-17,
#  'James Turner "Jim" Brewer': 1.5493221103154275e-17,
#  'Tommy Loren Burleson': 1.2769452478807562e-17,
#  'William Edward "Ed" Ratleff': -1.440618626075633e-18,
#  'Tayshaun Durell Prince': 0.15782024178932802,
#  'Michael Wesley Redd': 0.15782024178932813,
#  'Howard Earl "Howie" Williams': -5.446428931168344e-16,
#  'James Edward Harden, Jr.': 0.1467112340150154,
#  'Tyson Cleotis Chandler': 0.14671123401501546,
#  'Russell Westbrook, Jr.': 0.1467112340150154,
#  'Kevin Wesley Love': 0.14671123401501543,
#  'Jack Williamson Ragland': 8.027767901122249e-19,
#  'Phillip Gregory "Phil" Hubbard': 8.414772052968799e-17,
#  'William Quinn Buckner': 7.133912657378925e-17,
#  'Richard Allen Jefferson': 0.13025427616215665,
#  'Timothy Theodore "Tim" Duncan': 0.13025427616215662,
#  'Stephon Xavier Marbury': 0.13025427616215662,
#  'Shawn Dwayne Marion': 0.1302542761621566,
#  'Walter Paul Davis': 5.97588153533e-17,
#  'Thomas Joseph "Tom" LaGarde': 5.66625082235797e-17,
#  'Steven Bernard "Steve" Sheppard': 6.895285178340967e-17,
#  'Mitchell William "Mitch" Kupchak': 8.823039817430132e-17,
#  'Scott Glenn May': 6.234668868642637e-17,
#  'Philip Jackson "Phil" Ford, Jr.': 6.62685400043273e-17,
#  'Michel Taylor "Tate" Armstrong': 4.886979003189093e-17,
#  'Lamar Joseph Odom': 0.13025427616215668,
#  'Kenneth Alan "Kenny" Carr': 7.828681452276358e-17,
#  'Frank John Lubin': -1.4476890752373052e-17,
#  'Carl Stanley Knowles': -7.159535265738582e-18,
#  'Francis Lee Johnson': -1.6851006063291233e-17,
#  'Duane Alexander Swanson': -1.6412188516504757e-17,
#  'Donald Arthur "Don" Piper': 8.22341581620297e-18,
#  'Carl Leslie Shy': 3.1713273667554396e-18,
#  'Christopher Wesson "Chris" Bosh': 0.1578202417893281,
#  'Chukwuemeka Noubuisi "Emeka" Okafor': 0.13025427616215665,
#  'DeMarcus Amir Cousins': 0.08675377951546029,
#  'DeMar Darnell DeRozan': 0.08675377951546036,
#  'Dwight David Howard': 0.15782024178932813,
#  'Burdette Eliele "Burdie" Haldorson': -2.0803504134069623e-16,
#  'Calvin Bernard "Cal" Fowler': 9.408243159699248e-18,
#  'Donald Francis "Don" Dee': 2.3084621957680656e-19,
#  'Charles Thomas "Charlie" Scott': -7.035055059467992e-18,
#  'Carl Cecil Cain': -1.89197981946351e-16,
#  'Charles Frick "Chuck" Darling': -1.9824364006172196e-16,
#  'Draymond Jamal Green': 0.08675377951546033,
#  'Charles Monroe "Charlie" Hoag': -5.308815366723115e-16,
#  'Dan Luther Pippin': -5.170927846128966e-16,
#  'Clyde Edward Lovellette': -5.050524538369044e-16,
#  'Charles Edward Smith, IV': 0.01169320566083523,
#  'Charles Thomas "Tom" McMillen': -1.1368809300672292e-17,
#  'Dwight Elmo Jones': -2.531260707161607e-18,
#  'Charles Daniel H. Smith': 0.011693205660835222,
#  'Daniel Ricardo "Danny" Manning': 0.011693205660835228,
#  'Daniel Lewis "Dan" Majerle': 0.01169320566083523,
#  'Allen Ezail Iverson': 0.13025427616215668,
#  "Amar'e Carsares Stoudemire": 0.13025427616215662,
#  'Allan Wade Houston': 0.03927686378459821,
#  'Alonzo Harding Mourning': 0.039276863784598215,
#  'Antonio Keithflen McDyess': 0.039276863784598236,
#  'Alvin Cyrrale Robertson': 0.011572567846821985,
#  'Adrian Howard Smith': -5.699005307517072e-17,
#  'Earl Allen Kelley': -4.279244742275749e-17,
#  'Darrall Tucker Imhoff': -5.678348599625817e-17,
#  'Alexander John "Alex" Groza': -4.393491378013111e-16,
#  'Donald Argee "Don" Barksdale': -4.4105646566239576e-16,
#  'Clifford Eugene "Cliff" Barker': -4.066291033880579e-16,
#  'Arthur Owen "Art" Mollner': -2.6409867728800123e-18,
#  'Anthony Marshon Davis, Jr.': 0.14671123401501546,
#  'Andre Tyler Iguodala': 0.14671123401501546,
#  'Anfernee Deon "Penny" Hardaway': 0.02409389465584596,
#  'Earvin "Magic" Johnson, Jr.': 0.021545202099102902,
#  'Clyde Austin Drexler': 0.021545202099102895,
#  'Christian Donald Laettner': 0.02154520209910289}

# %% [markdown]
# ## 6. Compute degree centrality for the graph and print the top 5 nodes with the highest centrality.

# %%
degree_centrality = nx.degree_centrality(G)

degree_centrality
# Out:
# {'Carmelo Kyan Anthony': 0.18461538461538463,
#  'LeBron Raymone James': 0.13333333333333333,
#  'David Maurice Robinson': 0.14358974358974358,
#  'John Houston Stockton': 0.09230769230769231,
#  'Scottie Maurice Pippen': 0.09230769230769231,
#  'Christopher Emmanuel "Chris" Paul': 0.09230769230769231,
#  'Deron Michael Williams': 0.09230769230769231,
#  'Kobe Bean Bryant': 0.09230769230769231,
#  'Christopher Paul "Chris" Mullin': 0.10256410256410256,
#  'Michael Jeffrey Jordan': 0.10256410256410256,
#  'Dwyane Tyrone Wade, Jr.': 0.09743589743589744,
#  'Patrick Aloysius Ewing': 0.10256410256410256,
#  'Carlos Austin Boozer, Jr.': 0.09743589743589744,
#  'Karl Malone': 0.09230769230769231,
#  'Kevin Wayne Durant': 0.1076923076923077,
#  'Charles Wade Barkley': 0.09230769230769231,
#  'Mitchell James "Mitch" Richmond, III': 0.1076923076923077,
#  'Jerry Ray Lucas': 0.05641025641025641,
#  'Lester Everett "Les" Lane': 0.05641025641025641,
#  'Robert Lewis "Bob" Boozer': 0.05641025641025641,
#  'Oscar Palmer Robertson': 0.05641025641025641,
#  'Jeffrey Stephen "Jeff" Turner': 0.05641025641025641,
#  'Jon Francis Koncak': 0.05641025641025641,
#  'Jerry Franklin Shipp': 0.05641025641025641,
#  'William Warren "Bill" Bradley': 0.05641025641025641,
#  'Jay Joseph Hoyland Arnette': 0.05641025641025641,
#  'Terence Gilbert "Terry" Dischinger': 0.05641025641025641,
#  'Walter Raphael "Walt" Hazzard': 0.05641025641025641,
#  'Velvet James "Jim" Barnes': 0.05641025641025641,
#  'Richard Allen "Dick" Davies': 0.05641025641025641,
#  'Walter Jones "Walt" Bellamy, Jr.': 0.05641025641025641,
#  'Lucious Brown "Luke" Jackson, Jr.': 0.05641025641025641,
#  'Jesse Banard Renick': 0.06666666666666667,
#  'Kenneth Herman "Kenny" Rollins': 0.06666666666666667,
#  'Lewis William "Lew" Beck, Jr.': 0.06666666666666667,
#  'Ralph Milton Beard, Jr.': 0.06666666666666667,
#  'Raymond George "Ray" Lumpp': 0.06666666666666667,
#  'Robert Albert "Bob" Kurland': 0.13333333333333333,
#  'Robert C. "R. C." Pitts': 0.06666666666666667,
#  'Robert Lloyd Jackson "Jack" Robinson': 0.06666666666666667,
#  'Vincent Joseph "Vince" Boryla': 0.06666666666666667,
#  'Wallace Clayton "Wally" Jones': 0.06666666666666667,
#  'Jimmy Butler III': 0.05641025641025641,
#  'Melvin Grant "Mel" Counts': 0.05641025641025641,
#  'Joseph Louis "Joe" Caldwell': 0.05641025641025641,
#  'Lawrence Harvey "Larry" Brown': 0.05641025641025641,
#  'Joseph William "Joe" Kleine': 0.05641025641025641,
#  'Osie Leon Wood, III': 0.05641025641025641,
#  'Samuel Bruce "Sam" Perkins': 0.05641025641025641,
#  'Stephen Todd "Steve" Alford': 0.05641025641025641,
#  'Jeffrey "Jeff" Grayer': 0.05641025641025641,
#  'William Lloyd "Willie" Anderson, Jr.': 0.05641025641025641,
#  'Vernon "Vern" Fleming': 0.05641025641025641,
#  'Wayman Lawrence Tisdale': 0.05641025641025641,
#  'Jeffrey Vincent "Jeff" Mullins': 0.05641025641025641,
#  'John Paul "Pete" McCaffrey': 0.05641025641025641,
#  'Vernell Eufaye "Bimbo" Coles': 0.05641025641025641,
#  'Stacey Orlando Augmon': 0.05641025641025641,
#  'Jerome Alan "Jerry" West': 0.05641025641025641,
#  'Klay Alexander Thompson': 0.05641025641025641,
#  'John Frederick Keller': 0.06666666666666667,
#  'Ronald Yngve "Ron" Bontemps': 0.06666666666666667,
#  'Kyle Lowry': 0.05641025641025641,
#  'Kyrie Andrew Irving': 0.05641025641025641,
#  'Joseph Cephis "Joe" Fortenberry': 0.06666666666666667,
#  'William John "Bill" Wheatley': 0.06666666666666667,
#  'Willard Theodore Schmidt': 0.06666666666666667,
#  'Samuel J. "Sam" Balter, Jr.': 0.06666666666666667,
#  'Ralph English Bishop': 0.06666666666666667,
#  'John Richard Clawson': 0.05641025641025641,
#  'Wilmer Frederick "Bill" Hosket': 0.05641025641025641,
#  'Spencer Haywood': 0.05641025641025641,
#  'Michael Thomas "Mike" Barrett': 0.05641025641025641,
#  'Joseph Henry "Jo-Jo" White': 0.05641025641025641,
#  'Michael Barnwell "Mike" Silliman': 0.05641025641025641,
#  'William Barner "Bill" Lienhard': 0.06666666666666667,
#  'John Haskell "Tex" Gibbons': 0.06666666666666667,
#  'William Marion "Bill" Hougland': 0.12307692307692308,
#  'Victor Wayne Glasgow': 0.06666666666666667,
#  'Jason Frederick Kidd': 0.11282051282051282,
#  'Walter Ray Allen': 0.05641025641025641,
#  'Robert Earl "Bob" Kenney': 0.06666666666666667,
#  'Melvin Dean Kelley': 0.06666666666666667,
#  'Marcus Ross "Marc" Freiberger': 0.06666666666666667,
#  'Paul George': 0.05641025641025641,
#  'Larry Joe Bird': 0.05641025641025641,
#  'John Kenneth "Ken" Spain': 0.05641025641025641,
#  "Shaquille Rashuan O'Neal": 0.05641025641025641,
#  'Reginald Wayne "Reggie" Miller': 0.05641025641025641,
#  'Adrian Delano Dantley': 0.05641025641025641,
#  'Ernest "Ernie" Grunfeld': 0.05641025641025641,
#  'Vincent Lamont "Vin" Baker': 0.05641025641025641,
#  'Gordon C. Carpenter': 0.06666666666666667,
#  'Grant Henry Hill': 0.05641025641025641,
#  'Glynn Saulters': 0.05641025641025641,
#  'Hakeem Abdul Olajuwon': 0.05641025641025641,
#  'Vincent Lamar "Vince" Carter': 0.05641025641025641,
#  'Harrison Bryce Jordan Barnes': 0.05641025641025641,
#  'Hyland DeAndre Jordan, Jr.': 0.05641025641025641,
#  'James H. "Jim" King': 0.05641025641025641,
#  'Gilbert "Gib" Ford': 0.05641025641025641,
#  'Gary Dwayne Payton': 0.11282051282051282,
#  'Kevin Maurice Garnett': 0.05641025641025641,
#  'Timothy Duane "Tim" Hardaway': 0.05641025641025641,
#  'Steven Delano "Steve" Smith': 0.05641025641025641,
#  'William Fenton "Bill" Russell': 0.05641025641025641,
#  'Julius Shareef Abdur-Rahim': 0.05641025641025641,
#  'Frank Reilly McCabe': 0.06666666666666667,
#  'George "Jiff" Wilson': 0.05641025641025641,
#  'William Best "Billy" Evans': 0.05641025641025641,
#  'Ronald Paul "Ron" Tomsic': 0.05641025641025641,
#  'Robert Eugene "Bob" Jeangerard': 0.05641025641025641,
#  'Richard James "Dick" Boushka': 0.05641025641025641,
#  'K. C. Jones': 0.05641025641025641,
#  'James Patrick "Jim" Walsh': 0.05641025641025641,
#  'Herman "J. R." Reid, Jr.': 0.05641025641025641,
#  'Hersey R. Hawkins, Jr.': 0.05641025641025641,
#  'James Ricardo "Jim" Forbes': 0.05641025641025641,
#  'Thomas Edward "Tom" Henderson': 0.05641025641025641,
#  'Robert Clyde "Bobby" Jones': 0.05641025641025641,
#  'Paul Douglas "Doug" Collins': 0.05641025641025641,
#  'Michael Allen "Mike" Bantom': 0.05641025641025641,
#  'Kevin Francis Joyce': 0.05641025641025641,
#  'Kenneth Bryan "Kenny" Davis': 0.05641025641025641,
#  'James Turner "Jim" Brewer': 0.05641025641025641,
#  'Tommy Loren Burleson': 0.05641025641025641,
#  'William Edward "Ed" Ratleff': 0.05641025641025641,
#  'Tayshaun Durell Prince': 0.05641025641025641,
#  'Michael Wesley Redd': 0.05641025641025641,
#  'Howard Earl "Howie" Williams': 0.06666666666666667,
#  'James Edward Harden, Jr.': 0.05641025641025641,
#  'Tyson Cleotis Chandler': 0.05641025641025641,
#  'Russell Westbrook, Jr.': 0.05641025641025641,
#  'Kevin Wesley Love': 0.05641025641025641,
#  'Jack Williamson Ragland': 0.06666666666666667,
#  'Phillip Gregory "Phil" Hubbard': 0.05641025641025641,
#  'William Quinn Buckner': 0.05641025641025641,
#  'Richard Allen Jefferson': 0.05641025641025641,
#  'Timothy Theodore "Tim" Duncan': 0.05641025641025641,
#  'Stephon Xavier Marbury': 0.05641025641025641,
#  'Shawn Dwayne Marion': 0.05641025641025641,
#  'Walter Paul Davis': 0.05641025641025641,
#  'Thomas Joseph "Tom" LaGarde': 0.05641025641025641,
#  'Steven Bernard "Steve" Sheppard': 0.05641025641025641,
#  'Mitchell William "Mitch" Kupchak': 0.05641025641025641,
#  'Scott Glenn May': 0.05641025641025641,
#  'Philip Jackson "Phil" Ford, Jr.': 0.05641025641025641,
#  'Michel Taylor "Tate" Armstrong': 0.05641025641025641,
#  'Lamar Joseph Odom': 0.05641025641025641,
#  'Kenneth Alan "Kenny" Carr': 0.05641025641025641,
#  'Frank John Lubin': 0.06666666666666667,
#  'Carl Stanley Knowles': 0.06666666666666667,
#  'Francis Lee Johnson': 0.06666666666666667,
#  'Duane Alexander Swanson': 0.06666666666666667,
#  'Donald Arthur "Don" Piper': 0.06666666666666667,
#  'Carl Leslie Shy': 0.06666666666666667,
#  'Christopher Wesson "Chris" Bosh': 0.05641025641025641,
#  'Chukwuemeka Noubuisi "Emeka" Okafor': 0.05641025641025641,
#  'DeMarcus Amir Cousins': 0.05641025641025641,
#  'DeMar Darnell DeRozan': 0.05641025641025641,
#  'Dwight David Howard': 0.05641025641025641,
#  'Burdette Eliele "Burdie" Haldorson': 0.11282051282051282,
#  'Calvin Bernard "Cal" Fowler': 0.05641025641025641,
#  'Donald Francis "Don" Dee': 0.05641025641025641,
#  'Charles Thomas "Charlie" Scott': 0.05641025641025641,
#  'Carl Cecil Cain': 0.05641025641025641,
#  'Charles Frick "Chuck" Darling': 0.05641025641025641,
#  'Draymond Jamal Green': 0.05641025641025641,
#  'Charles Monroe "Charlie" Hoag': 0.06666666666666667,
#  'Dan Luther Pippin': 0.06666666666666667,
#  'Clyde Edward Lovellette': 0.06666666666666667,
#  'Charles Edward Smith, IV': 0.05641025641025641,
#  'Charles Thomas "Tom" McMillen': 0.05641025641025641,
#  'Dwight Elmo Jones': 0.05641025641025641,
#  'Charles Daniel H. Smith': 0.05641025641025641,
#  'Daniel Ricardo "Danny" Manning': 0.05641025641025641,
#  'Daniel Lewis "Dan" Majerle': 0.05641025641025641,
#  'Allen Ezail Iverson': 0.05641025641025641,
#  "Amar'e Carsares Stoudemire": 0.05641025641025641,
#  'Allan Wade Houston': 0.05641025641025641,
#  'Alonzo Harding Mourning': 0.05641025641025641,
#  'Antonio Keithflen McDyess': 0.05641025641025641,
#  'Alvin Cyrrale Robertson': 0.05641025641025641,
#  'Adrian Howard Smith': 0.05641025641025641,
#  'Earl Allen Kelley': 0.05641025641025641,
#  'Darrall Tucker Imhoff': 0.05641025641025641,
#  'Alexander John "Alex" Groza': 0.06666666666666667,
#  'Donald Argee "Don" Barksdale': 0.06666666666666667,
#  'Clifford Eugene "Cliff" Barker': 0.06666666666666667,
#  'Arthur Owen "Art" Mollner': 0.06666666666666667,
#  'Anthony Marshon Davis, Jr.': 0.05641025641025641,
#  'Andre Tyler Iguodala': 0.05641025641025641,
#  'Anfernee Deon "Penny" Hardaway': 0.05641025641025641,
#  'Earvin "Magic" Johnson, Jr.': 0.05641025641025641,
#  'Clyde Austin Drexler': 0.05641025641025641,
#  'Christian Donald Laettner': 0.05641025641025641}

# %% [markdown]
# ## 7. Generate a network visualization for the entire graph using a Kamada-Kawai force-directed layout.

# %%
plt.figure(figsize=(15,10))

nx.draw_kamada_kawai(G, node_size=80, alpha=0.75, width=0.75)
# Out:
# /usr/local/Cellar/jupyterlab/2.1.2/libexec/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
#
#
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.

# %% [markdown]
# ## 8. Create and visualize an ego graph for the player with the highest betweenness centrality.

# %%
plt.figure(figsize=(14,8))

ego = nx.ego_graph(G, 'Gary Dwayne Payton', radius=1)

# Draw the graph
nx.draw_kamada_kawai(ego, node_size=80, with_labels=True, alpha=0.8)

# %% [markdown]
# ## 9. Identify the communities within the entire graph and produce another visualization of it with the nodes color-coded by the community they belong to.

# %%
partition = louvain.best_partition(G)
values = list(partition.values())

plt.figure(figsize=(14,8))

# Do the plot
nx.draw_kamada_kawai(G, node_size=100, alpha=0.8, width=0.5,node_color=values, cmap="jet")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-394df980ee0b> in <module>
# ----> 1 partition = louvain.best_partition(G)
#       2 values = list(partition.values())
#       3
#       4 plt.figure(figsize=(14,8))
#       5
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %% [markdown]
# ## Bonus: Hierarchical Graphs
#
# Thus far, we have analyzed graphs where the nodes represented individual players and the edges represented Olympic games that they have competed in together. We can analyze the data at a higher level if we wanted to, strippping out the players as entities and analyzing the data at the Games level. To do this, we would need to reconstruct the graph so that the *Games* field represents the entities and then use the player names as the edge criteria so that there would be an edge between two Olympic games if an player played in both of them. You already have the tools in your toolbox to be able to do this, so give it a try.

# %% [markdown]
# ### Create a graph with Games as the entities and then print out the graph statistics.

# %% [markdown]
# ### Generate a network visualization of this graph using the layout of your choice.
